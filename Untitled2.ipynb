# %%
import pandas as pd
df1 = pd.read_excel('r1.xlsx', engine='openpyxl') #error_bad_lines=False

# %%
df2 = pd.read_excel('r2.xlsx', engine='openpyxl')

# %%
df3 = pd.read_excel('mopup.xlsx', engine='openpyxl')
df3
# Out:
#      Allotted Quota                                 Allotted Institute  \
# 0         All India  Acharya Harihar Post Graduate Institute of Can...
# 1         All India  ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC...
# 2         All India  ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC...
# 3         All India  ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC...
# 4         All India  ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC...
# ...             ...                                                ...
# 3892      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 3893      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 3894      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 3895      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 3896      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
#
#                                                  Course Alloted Category  \
# 0                                M.D. (ANAESTHESIOLOGY)               ST
# 1                                    M.D. (PAEDIATRICS)              OBC
# 2     M.D. (Tuberculosis and Respiratory diseases)/P...              OBC
# 3                                  M.S. (OPHTHALMOLOGY)             Open
# 4                                M.D. (ANAESTHESIOLOGY)             Open
# ...                                                 ...              ...
# 3892                                  M.D. (PHYSIOLOGY)             Open
# 3893                                M.D. (BIOCHEMISTRY)              OBC
# 3894                                M.D. (PHARMACOLOGY)               ST
# 3895                                    MD/MS (Anatomy)              OBC
# 3896                                    MD/MS (Anatomy)               SC
#
#       Cutoff Rank
# 0           74458
# 1            6377
# 2            9808
# 3           17498
# 4           18969
# ...           ...
# 3892       121533
# 3893       135597
# 3894       141458
# 3895       143828
# 3896       153593
#
# [3897 rows x 5 columns]

# %%
df4 = pd.read_excel('stray.xlsx', engine='openpyxl')

# %%
df5 = pd.read_excel('sp_stray.xlsx', engine='openpyxl')

# %%
# result = df1.groupby('Alloted Category')
# cat = set(df1['Alloted Category'])
dict_r1 = df1.to_dict('records')
dict_r2 = df2.to_dict('records')
dict_mopup = df3.to_dict('records')
dict_stray = df4.to_dict('records')
dict_sp_stray = df5.to_dict('records')

# %%
# course = set(df1['Course'])
# len(course)
# course
# {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Lala Lajpat Rai Memorial Medical College, MEERUT,Lala Lajpat Rai Memorial Medical College, MEERUT, Uttar Pradesh, 250004',
#   'Course': 'DIP. IN DERM.  VENEREOLOGY and LEPROSY/DERMATOLOGY /VENEREOLOGY and DERMATOLOGY/LEPROSY/VENEREAL DISEASE and LEPROSY',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 14409}

# %%
def remove(string):
    return string.replace(" ", "")

# %%
df2_records_not_in_df1=[]
for row in dict_r2:
    match = False
    for row1 in dict_r1:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df2_records_not_in_df1.append(row) 
#     if row in dict_r1:
#         r1_r2_data.append(row)
df2_records_not_in_df1
# ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004
# Out:
# [{'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.D. (PAEDIATRICS)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 4426},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.D. (PAEDIATRICS)',
#   'Alloted Category': 'EWS',
#   'Cutoff Rank': 5834},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.D. (Tuberculosis and Respiratory diseases)/Pulmonary Medicine /M.D.(Respiratory Medicine)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 6377},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.D. (PSYCHIATRY)',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 14733},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.D. (ANAESTHESIOLOGY)',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 15151},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.S. (OPHTHALMOLOGY)',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 16124},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.D. (Tuberculosis and Respiratory diseases)/Pulmonary Medicine /M.D.(Respiratory Medicine)',
#   'Alloted Category': 'SC',
#   'Cutoff Rank': 22580},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.S. (OPHTHALMOLOGY)',
#   'Alloted Category': 'SC',
#   'Cutoff Rank': 32223},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.D. (PAEDIATRICS)',
#   'Alloted Category': 'ST',
#   'Cutoff Rank': 34144},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC Subbareddy Stadium Dargamitta Nellore,Andhra Pradesh,524004',
#   'Course': 'M.D. (PREVENTIVE and SOCIAL MEDICINE)/ COMMUNITY MEDICINE',
#   'Alloted Category': 'Open',
#   'Cutoff Rank':

#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Maharashtra Post Graduate Institute of Medical Education and Research,Nashik,Maharashtra Post Graduation Institute Of Medical Education and Research Civil Hospital campus Trimba,Maharashtra,422002',
#   'Course': 'M.D. (ANAESTHESIOLOGY)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 19660},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Maharashtra Post Graduate Institute of Medical Education and Research,Nashik,Maharashtra Post Graduation Institute Of Medical Education and Research Civil Hospital campus Trimba,Maharashtra,422002',
#   'Course': 'M.S. (GENERAL SURGERY)',
#   'Alloted Category': 'SC',
#   'Cutoff Rank': 25371},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Maharashtra Post Graduate Institute of Medical Education and Research,Nashik,Maharashtra Post Graduation Institute Of Medical Education and Research Civil Hospital campus Trimba,Maharashtra,422002',
#   'Course': 'M.S. (GENERAL SURGERY)',
#   'Alloted Category': 'ST',
#   'Cutoff Rank': 48851},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Mahatma Gandhi Memorial Medical College,Indore,Mahatma Gandhi Memorial Medical College,Indore,Madhya Pradesh,452001',
#   'Course': 'M.D. (PSYCHIATRY)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 14068},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Moti Lal Nehru Medical College,Moti Lal Nehru Medical College,Uttar Pradesh,211001',
#   'Course': 'M.D. (RADIO-DIAGNOSIS)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 1318},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Moti Lal Nehru Medical College,Moti Lal Nehru Medical College,Uttar Pradesh,211001',
#   'Course': 'M.D. (DERM.,VENE. and LEPROSY)/ (DERMATOLOGY)/(SKIN and VENEREALDISEASES)/(VENEREOLOGY)',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 1808},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Moti Lal Nehru Medical College,Moti Lal Nehru Medical College,Uttar Pradesh,211001',
#   'Course': 'M.D. (DERM.,VENE. and LEPROSY)/ (DERMATOLOGY)/(SKIN and VENEREALDISEASES)/(VENEREOLOGY)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 3748},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Moti Lal Nehru Medical College,Moti Lal Nehru Medical College,Uttar Pradesh,211001',
#   'Course': 'M.D. (RADIO-DIAGNOSIS)',
#   'Alloted Category': 'ST',
#   'Cutoff Rank': 14257},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Moti Lal Nehru Medical College,Moti Lal Nehru Medical College,Uttar Pradesh,211001',
#   'Course': 'M.D. IN TRANSFUSION MEDICINE/ IMMUNO- HAEMATOLOGY and BLOOD TRANSFUSION',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 28662},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Moti Lal Nehru Medical College,Moti Lal Nehru Medical College,Uttar Pradesh,211001',
#   'Course': 'M.D. (MICROBIOLOGY)',
#   'Alloted Category': 'SC',
#   'Cutoff Rank': 89643},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rajendra Institute of Medical Sciences,Ranchi,Rajendra Institute of Medical Sciences,Ranchi,Jharkhand,834009',
#   'Course': 'M.D. (MICROBIOLOGY)',
#   'Alloted Category': 'EWS',
#   'Cutoff Rank': 72647},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rajiv Gandhi Institute of Medical Sciences Srikakulam,Rajiv Gandhi Institute of Medical Sciences Srikakulam,Andhra Pradesh,532001',
#   'Course': 'M.S. (GENERAL SURGERY)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 9058},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rajiv Gandhi Institute of Medical Sciences Srikakulam,Rajiv Gandhi Institute of Medical Sciences Srikakulam,Andhra Pradesh,532001',
#   'Course': 'M.S. (E.N.T.)',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 15901},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rims Medical College,Ongole,GOVERNMENT MEDICAL COLLEGE RIMS ONGOLE,Andhra Pradesh,523001',
#   'Course': 'M.S. (GENERAL SURGERY)',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 10230},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rajkiya Medical College,Jalaun,kalpi Road orai Jalaun,Uttar Pradesh,285001',
#   'Course': 'M.S. (GENERAL SURGERY)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 12583},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rims Medical College,Ongole,GOVERNMENT MEDICAL COLLEGE RIMS ONGOLE,Andhra Pradesh,523001',
#   'Course': 'M.D. (PSYCHIATRY)',
#   'Alloted Category': 'EWS',
#   'Cutoff Rank': 24074},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rims Medical College,Ongole,GOVERNMENT MEDICAL COLLEGE RIMS ONGOLE,Andhra Pradesh,523001',
#   'Course': 'M.D. (FORENSIC MEDICINE)',
#   'Alloted Category': 'Open',
#   'Cutoff Rank': 68693},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rims Medical College,Ongole,GOVERNMENT MEDICAL COLLEGE RIMS ONGOLE,Andhra Pradesh,523001',
#   'Course': 'M.D. (MICROBIOLOGY)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 84253},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'Rims Medical College,Ongole,GOVERNMENT MEDICAL COLLEGE RIMS ONGOLE,Andhra Pradesh,523001',
#   'Course': 'M.D. (PHYSIOLOGY)',
#   'Alloted Category': 'OBC',
#   'Cutoff Rank': 92813},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'THANJAVUR MEDICAL COLLEGE,THANJAVUR,THANJAVUR MEDICAL COLLEGE,THANJAVUR,Tamil Nadu,613004',
#   'Course': 'M.D. (Emergency and Critical Care)/M.D. (Emergency Medicine)',
#   'Alloted Category': 'EWS',
#   'Cutoff Rank': 10723},
#  {'Allotted Quota': 'All India',
#   'Allotted Institute': 'THANJAVUR MEDICAL COLLEGE,THANJAVUR,THANJAVUR MEDICAL COLLEGE,THANJAVUR,Tamil Nadu,613004',
#   'Course': 'M.D. (Emergency and Critical Care)/M.D. (Emergency Medicine)',
#   'Alloted Category': 'SC',
#   'Cutoff Rank': 24356}]

# %%
len(df2_records_not_in_df1) #99
# df2_records_not_in_df1
# Out:
# 99

# %%
df3_records_not_in_df1=[]
for row in dict_mopup:
    match = False
    for row1 in dict_r1:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df3_records_not_in_df1.append(row)

# %%
len(df3_records_not_in_df1) #464
# df3_records_not_in_df1
# Out:
# 464

# %%
df3_records_not_in_df2=[]
for row in dict_mopup:
    match = False
    for row1 in dict_r2:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df3_records_not_in_df2.append(row)

# %%
len(df3_records_not_in_df2) #719
# Out:
# 719

# %%
df4_records_not_in_df1=[]
for row in dict_stray:
    match = False
    for row1 in dict_r1:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df4_records_not_in_df1.append(row)

# %%
len(df4_records_not_in_df1) #189
# Out:
# 189

# %%
df4_records_not_in_df2=[]
for row in dict_stray:
    match = False
    for row1 in dict_r2:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df4_records_not_in_df2.append(row)

# %%
len(df4_records_not_in_df2) #277
# Out:
# 277

# %%
df4_records_not_in_mopup=[]
for row in dict_stray:
    match = False
    for row1 in dict_mopup:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df4_records_not_in_mopup.append(row)

# %%
len(df4_records_not_in_mopup) #75
# Out:
# 75

# %%
df5_records_not_in_df1=[]
for row in dict_sp_stray:
    match = False
    for row1 in dict_r1:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df5_records_not_in_df1.append(row)

# %%
len(df5_records_not_in_df1) #111
# Out:
# 111

# %%
df5_records_not_in_df2=[]
for row in dict_sp_stray:
    match = False
    for row1 in dict_r2:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df5_records_not_in_df2.append(row)

# %%
len(df5_records_not_in_df2) #118
# Out:
# 118

# %%
df5_records_not_in_mopup=[]
for row in dict_sp_stray:
    match = False
    for row1 in dict_mopup:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df5_records_not_in_mopup.append(row)

# %%
len(df5_records_not_in_mopup) #63
# Out:
# 63

# %%
df5_records_not_in_stray=[]
for row in dict_sp_stray:
    match = False
    for row1 in dict_stray:
        if remove(row['Allotted Institute'].lower())==remove(row1['Allotted Institute'].lower()) and remove(row['Course'].lower())==remove(row1['Course'].lower()) and remove(row['Alloted Category'].lower())==remove(row1['Alloted Category'].lower()):
            match=True
    if not match:
        df5_records_not_in_stray.append(row)

# %%
len(df5_records_not_in_stray) #70
# Out:
# 70

# %%
df1 = df1.rename(columns={'Cutoff Rank': 'R1'})
# dict_r1 = df1.to_dict('records')
# for dict1 in dict_r1:
#     if dict1 in df2_records_not_in_df1:
#         dict_r1['R2']='-'
#     if dict1 in df3_records_not_in_df1:
#         dict_r1['Mop Up']='-'
        
df1['R2']='-'
df1['Mop Up']='-'
df1['Stray Vacancy']='-'
df1['SP Stray Vacancy']='-'
df1
# Out:
#      Allotted Quota                                 Allotted Institute  \
# 0         All India  Acharya Harihar Post Graduate Institute of Can...
# 1         All India  Agartala Government Medical College,Agartala G...
# 2         All India  Agartala Government Medical College,Agartala G...
# 3         All India  Agartala Government Medical College,Agartala G...
# 4         All India  Agartala Government Medical College,Agartala G...
# ...             ...                                                ...
# 7129      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 7130      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 7131      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 7132      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 7133      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
#
#                        Course Alloted Category     R1 R2 Mop Up Stray Vacancy  \
# 0      M.D. (ANAESTHESIOLOGY)               ST  47316  -      -             -
# 1      M.D. (RADIO-DIAGNOSIS)             Open   2071  -      -             -
# 2     M.D. (GENERAL MEDICINE)             Open   2629  -      -             -
# 3      M.D. (RADIO-DIAGNOSIS)              OBC   3451  -      -             -
# 4          M.D. (PAEDIATRICS)             Open   5342  -      -             -
# ...                       ...              ...    ... ..    ...           ...
# 7129      M.D. (PHARMACOLOGY)               SC  77306  -      -             -
# 7130      M.D. (PHARMACOLOGY)              OBC  84754  -      -             -
# 7131        M.D. (PHYSIOLOGY)             Open  85206  -      -             -
# 7132      M.D. (PHARMACOLOGY)               ST  91579  -      -             -
# 7133      M.D. (BIOCHEMISTRY)              OBC  98585  -      -             -
#
#      SP Stray Vacancy
# 0                   -
# 1                   -
# 2                   -
# 3                   -
# 4                   -
# ...               ...
# 7129                -
# 7130                -
# 7131                -
# 7132                -
# 7133                -
#
# [7134 rows x 9 columns]

# %%
df2 = df2.rename(columns={'Cutoff Rank': 'R2'})
        
df2['R1']='-'
df2['Mop Up']='-'
df2['Stray Vacancy']='-'
df2['SP Stray Vacancy']='-'
df2
# Out:
#      Allotted Quota                                 Allotted Institute  \
# 0         All India  Acharya Harihar Post Graduate Institute of Can...
# 1         All India  ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC...
# 2         All India  ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC...
# 3         All India  ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC...
# 4         All India  ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC...
# ...             ...                                                ...
# 5765      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 5766      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 5767      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 5768      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
# 5769      All India  VSS INSTITUTE OF MEDICAL SCIENCES AND RESEARCH...
#
#                                                  Course Alloted Category  \
# 0                                M.D. (ANAESTHESIOLOGY)               ST
# 1                                    M.D. (PAEDIATRICS)              OBC
# 2                                    M.D. (PAEDIATRICS)              EWS
# 3     M.D. (Tuberculosis and Respiratory diseases)/P...              OBC
# 4                                     M.D. (PSYCHIATRY)             Open
# ...                                                 ...              ...
# 5765  M.D. (PREVENTIVE and SOCIAL MEDICINE)/ COMMUNI...               SC
# 5766                                M.D. (MICROBIOLOGY)              OBC
# 5767                                M.D. (BIOCHEMISTRY)             Open
# 5768                           M.D. (FORENSIC MEDICINE)              OBC
# 5769                                M.D. (PHARMACOLOGY)               ST
#
#           R2 R1 Mop Up Stray Vacancy SP Stray Vacancy
# 0      71593  -      -             -                -
# 1       4426  -      -             -                -
# 2       5834  -      -             -                -
# 3       6377  -      -             -                -
# 4      14733  -      -             -                -
# ...      ... ..    ...           ...              ...
# 5765   64612  -      -             -                -
# 5766   84754  -      -             -                -
# 5767   85052  -      -             -                -
# 5768  100300  -      -             -                -
# 5769  104320  -      -             -                -
#
# [5770 rows x 9 columns]

# %%
df3 = df3.rename(columns={'Cutoff Rank': 'Mop Up'})
        
df3['R1']='-'
df3['R2']='-'
df3['Stray Vacancy']='-'
df3['SP Stray Vacancy']='-'

# %%
df4 = df4.rename(columns={'Cutoff Rank': 'Stray Vacancy'})
        
df4['R1']='-'
df4['R2']='-'
df4['Mop Up']='-'
df4['SP Stray Vacancy']='-'

# %%
df5 = df5.rename(columns={'Cutoff Rank': 'SP Stray Vacancy'})
        
df5['R1']='-'
df5['R2']='-'
df5['Mop Up']='-'
df5['Stray Vacancy']='-'

# %%
final_df = pd.concat([df1, df2, df3, df4, df5], axis=0)
final_df = final_df.groupby(['Allotted Institute', 'Course', 'Alloted Category']).sum()
# final_df = final_df.groupby('Allotted Institute').max().reset_index()

# final_df.to_csv("final_data.csv")
# table = pd.pivot_table(final_df, values=['R1','R2','Mop Up', 'Stray Vacancy', 'SP Stray Vacancy'], index=['Allotted Institute', 'Course', 'Alloted Category'],
#                     columns=['C'], aggfunc=np.sum)
final_df
# Out:
#                                                                                                                        Allotted Quota
# Allotted Institute                                 Course                                             Alloted Category
# ACSR GOVERNMENT MEDICAL COLLEGE,NELLORE,Opp AC ... M.D. (ANAESTHESIOLOGY)                             Open                  All India
#                                                    M.D. (PAEDIATRICS)                                 EWS                   All India
#                                                                                                       OBC                   All India
#                                                                                                       ST                    All India
#                                                    M.D. (PREVENTIVE and SOCIAL MEDICINE)/ COMMUNIT... Open                  All India
# ...                                                                                                                               ...
# Veer Chandra Singh Garhwali Govt.Institute of M... M.D. (PHARMACOLOGY)                                OBC                   All India
#                                                    M.D. (PHYSIOLOGY)                                  Open                  All India
#                                                    M.D. (PREVENTIVE and SOCIAL MEDICINE)/ COMMUNIT... OBC                   All India
#                                                                                                       Open                  All India
#                                                    M.S. (OPHTHALMOLOGY)                               SC                    All India
#
# [8992 rows x 1 columns]

# %%
# column = ['Allotted Quota', 'Allotted Institute', 'Course', 'Alloted Category', 'Cutoff Rank']
# final_data=[]
# temp_data = []
# for dr1 in dict_r1:
#     for dr2 in dict_r2:
#         if remove(dr1['Allotted Institute'])==remove(dr2['Allotted Institute']) and dr1['Course']==dr2['Course'] and dr1['Alloted Category']==dr2['Alloted Category']:
#             dr1['r2'] = dr2['Cutoff Rank']
#             if dr1 not in final_data:
#                 final_data.append(dr1)
#         else:
#             print("dr1....", dr1)
#             print("dr2....", dr2)
#             dr1['r2'] = '-'
#             dr2['r2'] = '-'
#             if dr1 not in final_data:
#                 final_data.append(dr1)
#             if dr2 not in final_data:
#                 final_data.append(dr2)

# %%
# data={}
# col = ['Allotted Quota', 'Allotted Institute', 'Course', 'Alloted Category', 'Cutoff Rank']
# for data1 in df1:
#     for c in col:
#         if data1==c:
#             data[c]=df1[data1][0]
            
# data
#7043
#5610
# len(final_data)
# final_data
