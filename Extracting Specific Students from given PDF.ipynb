# %%
import pandas as pd
df_list = []
for k in range(1, 273):
    sheet_name = "Table"+" "+str(k)
    all_data = pd.read_excel("D:\Coding Boot Camp\MS-1-300\medical-student_1_300.xlsx", index_col=0, sheet_name=sheet_name, engine='openpyxl')
    df_list.append(all_data)
all_df_data = pd.concat(df_list)
all_df_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-07dca036291b> in <module>
#       3 for k in range(1, 301):
#       4     sheet_name = "Table"+" "+str(k)
# ----> 5     all_data = pd.read_excel("D:\Coding Boot Camp\MS-1-300\medical-student_1_300.xlsx", index_col=0, sheet_name=sheet_name, engine='openpyxl')
#       6     df_list.append(all_data)
#       7 all_df_data = pd.concat(df_list)
#
# c:\users\khanmoh\appdata\local\programs\python\python36\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
for l in range(1, 271):
    sheet_name = "Table"+" "+str(l)
    all_data = pd.read_excel("D:\Coding Boot Camp\MS-1-300\medical-student_301_600.xlsx", index_col=0, sheet_name=sheet_name, engine='openpyxl')
    df_list.append(all_data)

# %%
for m in range(1, 219):
    sheet_name = "Table"+" "+str(m)
    all_data = pd.read_excel("D:\Coding Boot Camp\MS-1-300\medical-student_601_860.xlsx", index_col=0, sheet_name=sheet_name, engine='openpyxl')
    df_list.append(all_data)

# %%
all_df_data = pd.concat(df_list)
all_df_data.head()
len(df_list)
# Out:
# 760

# %%
# Displaying all the rows that has NaN
# naNValue = all_df_data[all_df_data.isna().any(axis=1)]
# display(naNValue.head())
all_df_data = all_df_data.dropna(how='all')
# all_df_data = all_df_data.dropna(thresh=35439, axis=1)
# # all_data = all_data.drop("Unnamed: 10", axis=1, inplace=True)
# del all_df_data['Unnamed: 10']
all_df_data
# Out:
#                AIR NEET\nRoll No. CET Form. No. Reg. Sr No.  \
# 1            28150     3114016174     211009282        2032
# 2            33151     3109102683     211013317        2459
# 3            36220     3110104521     211049568        2677
# 4            36537     3115034234     211000004        2707
# 5            36575     3112012169     211000828        2711
# ...            ...            ...           ...         ...
# 35435  1.54385e+06      3.119e+09    2.1106e+08       57523
# 35436  1.54397e+06       3.12e+09   2.11023e+08       57524
# 35437  1.54404e+06    3.11204e+09   2.11031e+08       57525
# 35438   1.5441e+06      2.208e+09   2.11047e+08       57526
# 35439  1.54416e+06    3.10401e+09    2.1101e+08       57527
#
#                           Name  G Cat.  \
# 1        PARANJPE MUKTA MANDAR  F  NaN
# 2         PAWAR KRISHNA DASRAO  M  VJA
# 3       VISHAL ARUNKUMAR SINGH  M  NaN
# 4        MANTE GANESH SHIVHARI  M  NTD
# 5      KANDHARE ADARSH BALIRAM  M  EWS
# ...

# %%
del all_df_data['Unnamed: 10']
del all_df_data['\uf0df-----Current Selection Details                \uf0e0\nQuota                      Code College']
del all_df_data['Unnamed: 11']
del all_df_data['Unnamed: 15']
del all_df_data['Unnamed: 8']
del all_df_data['Unnamed: 5']
del all_df_data['Unnamed: 16']
del all_df_data['Unnamed: 17']
del all_df_data['Unnamed: 18']
del all_df_data['Unnamed: 19']
del all_df_data['Unnamed: 20']
del all_df_data['Unnamed: 21']
del all_df_data['Unnamed: 7']
del all_df_data['Unnamed: 22']
del all_df_data['Unnamed: 1']
del all_df_data['Unnamed: 2']
del all_df_data['Unnamed: 4']
del all_df_data['Unnamed: 6']
del all_df_data['Unnamed: 23']
del all_df_data['NEET']
del all_df_data['CET Form.']
del all_df_data['Reg.']
del all_df_data['\uf0df-----Current Selection Details                \uf0e0']
del all_df_data['\uf0df-----Current Selection Quota']
list(all_df_data)
# Out:
# ['AIR',
#  'NEET\nRoll No.',
#  'CET Form. No.',
#  'Reg. Sr No.',
#  'Name',
#  'G',
#  'Cat.',
#  'Unnamed: 9',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 3',
#  'Details                \uf0e0\nCode College']

# %%
del all_df_data['Unnamed: 3']
del all_df_data['Details                \uf0e0\nCode College']
all_df_data
# Out:
#                AIR NEET\nRoll No. CET Form. No. Reg. Sr No.  \
# 1            28150     3114016174     211009282        2032
# 2            33151     3109102683     211013317        2459
# 3            36220     3110104521     211049568        2677
# 4            36537     3115034234     211000004        2707
# 5            36575     3112012169     211000828        2711
# ...            ...            ...           ...         ...
# 35435  1.54385e+06      3.119e+09    2.1106e+08       57523
# 35436  1.54397e+06       3.12e+09   2.11023e+08       57524
# 35437  1.54404e+06    3.11204e+09   2.11031e+08       57525
# 35438   1.5441e+06      2.208e+09   2.11047e+08       57526
# 35439  1.54416e+06    3.10401e+09    2.1101e+08       57527
#
#                           Name  G Cat. Unnamed: 9 Unnamed: 12 Unnamed: 13  \
# 1        PARANJPE MUKTA MANDAR  F  NaN       OPEN    3108:RSM         NaN
# 2         PAWAR KRISHNA DASRAO  M  VJA       OPEN    3101:RAP         NaN
# ...

# %%
all_df_data.fillna('', inplace=True)
all_df_data.head()
# Out:
# c:\users\khanmoh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#      AIR NEET\nRoll No. CET Form. No. Reg. Sr No.                     Name  G  \
# 1  28150     3114016174     211009282        2032    PARANJPE MUKTA MANDAR  F
# 2  33151     3109102683     211013317        2459     PAWAR KRISHNA DASRAO  M
# 3  36220     3110104521     211049568        2677   VISHAL ARUNKUMAR SINGH  M
# 4  36537     3115034234     211000004        2707    MANTE GANESH SHIVHARI  M
# 5  36575     3112012169     211000828        2711  KANDHARE ADARSH BALIRAM  M
#
#   Cat. Unnamed: 9 Unnamed: 12 Unnamed: 13               Unnamed: 14
# 1            OPEN    3108:RSM              TILAK AC PUNE(Canc./NJ.)
# ...

# %%
all_df_data["Code - College"] = all_df_data["Unnamed: 12"]+all_df_data["Unnamed: 13"]+all_df_data["Unnamed: 14"]
all_df_data.head()
# Out:
# c:\users\khanmoh\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      AIR NEET\nRoll No. CET Form. No. Reg. Sr No.                     Name  G  \
# 1  28150     3114016174     211009282        2032    PARANJPE MUKTA MANDAR  F
# 2  33151     3109102683     211013317        2459     PAWAR KRISHNA DASRAO  M
# 3  36220     3110104521     211049568        2677   VISHAL ARUNKUMAR SINGH  M
# 4  36537     3115034234     211000004        2707    MANTE GANESH SHIVHARI  M
# 5  36575     3112012169     211000828        2711  KANDHARE ADARSH BALIRAM  M
#
# ...

# %%
del all_df_data["Unnamed: 12"]
del all_df_data["Unnamed: 13"]
del all_df_data["Unnamed: 14"]

# %%
all_df_data.rename(columns={'Unnamed: 9': 'Quota'}, inplace=True)
all_df_data.head()
# Out:
#      AIR NEET Roll No. CET Form. No. Reg. Sr No.                     Name  G  \
# 1  28150    3114016174     211009282        2032    PARANJPE MUKTA MANDAR  F
# 2  33151    3109102683     211013317        2459     PAWAR KRISHNA DASRAO  M
# 3  36220    3110104521     211049568        2677   VISHAL ARUNKUMAR SINGH  M
# 4  36537    3115034234     211000004        2707    MANTE GANESH SHIVHARI  M
# 5  36575    3112012169     211000828        2711  KANDHARE ADARSH BALIRAM  M
#
#   Cat. Quota                    Code - College Last Name First Name
# 1       OPEN  3108:RSMTILAK AC PUNE(Canc./NJ.)    MANDAR   PARANJPE
# 2  VJA  OPEN      3101:RAPAC MUMBAI(Canc./NJ.)    DASRAO      PAWAR
# 3       OPEN      3101:RAPAC MUMBAI(Canc./NJ.)     SINGH     VISHAL
# 4  NTD  OPEN      3101:RAPAC MUMBAI(Canc./NJ.)  SHIVHARI      MANTE
# 5  EWS  OPEN      3101:RAPAC MUMBAI(Canc./NJ.)   BALIRAM   KANDHARE

# %%
all_df_data.rename(columns={'NEET\nRoll No.': 'NEET Roll No.'}, inplace=True)
all_df_data.head()
all_df_data.to_csv('medical-students-admission.csv', index=False)
# Out:
# c:\users\khanmoh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
m_name = pd.read_excel("D:\Coding Boot Camp\muslim-names11.xlsx", engine='openpyxl')
m_name = m_name.dropna(how='all')
# m_name.head()

name_list = m_name["Name"].tolist()
muslim_name = []+["SANA"]
raw_name=["Aman","Amber","Sham","Diya","Rani","Roshan","Gulab","Naman","Sahil","Seema","Sameer","Uday","Sikandar","Samir", "SHAH"]
commom_name = []
for j in raw_name:
    b = j.upper()
    commom_name.append(b)
print(commom_name)
for i in name_list:
    if len(i) > 2:
        a = i.upper()
        if a not in commom_name:
            muslim_name.append(a)
# print(muslim_name)
# Out:
# ['AMAN', 'AMBER', 'SHAM', 'DIYA', 'RANI', 'ROSHAN', 'GULAB', 'NAMAN', 'SAHIL', 'SEEMA', 'SAMEER', 'UDAY', 'SIKANDAR', 'SAMIR', 'SHAH']

# %%
#Surname
m_surname = pd.read_excel("D:\Coding Boot Camp\surname.xlsx", engine='openpyxl')
m_surname.head()
surname_list = m_surname["Surname"].tolist()
muslim_surname = []
for i in surname_list:
    a = i.upper()
    if a not in commom_name:
        muslim_surname.append(a)

all_name=muslim_surname+muslim_name
"SANA" in all_name
# Out:
# True

# %%
def get_city(x):
    l=len(x.split(' '))
    if l > 4:
        return x.split(' ')[3]
    elif l >= 3 and l<4:
        return x.split(' ')[2]
    elif l >= 2 and l<3:
        return x.split(' ')[1]
    return x.split(' ')[0]

def get_state(y):
    return y.split(' ')[0]


all_df_data['Last Name'] = all_df_data['Name'].apply(lambda x: f"{get_city(x)}")
all_df_data['First Name'] = all_df_data['Name'].apply(lambda y: f"{get_state(y)}")
all_df_data
# Out:
# c:\users\khanmoh\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# c:\users\khanmoh\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#                AIR NEET Roll No. CET Form. No. Reg. Sr No.  \
# 1            28150    3114016174     211009282        2032
# ...

# %%
bucket=[]

for k in all_name:
    #ln
    ln_df = all_df_data[all_df_data['Last Name'] == k]
    if not ln_df.empty:
        bucket.append(ln_df)
    #fn
    fn_df = all_df_data[all_df_data['First Name'] == k]
    if not fn_df.empty:
        bucket.append(fn_df)

# %%
len(bucket)
bucket[0]
# Out:
#            AIR NEET Roll No. CET Form. No. Reg. Sr No.                 Name  \
# 3353.0  156277     3.104e+09   2.11018e+08       12714  SHAIKH NAZEEM ABBAS
# 17982   563596    3101014157     211022699       35167    SHAIKH AKIB ABBAS
#
#         G Cat.             Quota Code - College Last Name First Name
# 3353.0  M  EWS  AIOPEN     (A.I)                    ABBAS     SHAIKH
# 17982   M  NTB                                      ABBAS     SHAIKH

# %%
df_results = pd.concat(bucket)
results = df_results.drop_duplicates()

# %%
import numpy as np
# del results["Sr. No."]
results.index = np.arange(len(results))
results.index += 1
results
# Out:
#          AIR NEET Roll No. CET Form. No. Reg. Sr No.  \
# 1     156277     3.104e+09   2.11018e+08       12714
# 2     563596    3101014157     211022699       35167
# 3     285484    3112003248     211008941       21465
# 4     516188    3112001464     211025717       33274
# 5      98564    3115001315     211029186        8220
# ...      ...           ...           ...         ...
# 2882  488365    3114003002     211011655       32113
# 2883  372985   3.11301e+09   2.11037e+08       26627
# 2884  612998   3.11012e+09   2.11035e+08       36900
# 2885  320168    3112107346     211006263       23631
# 2886  328413    3110015004     211020104       24125
#
#                            Name  G Cat.  \
# 1           SHAIKH NAZEEM ABBAS  M  EWS
# 2             SHAIKH AKIB ABBAS  M  NTB
# 3          MUJTABA AHMED ABBASI  M  NTB
# 4              TUBA ANAM ABBASI  F
# 5     MOHAMMAD MUSADDIQUE ABDUL  M  OBC
# ...                         ... ..  ...
# 2882           KHOT ABID ZAMEER  M  EWS
# ...

# %%
del results["First Name"]
del results["Last Name"]

# %%
results.to_csv('muslim_students_only1.csv')

# %%
results[results['G'] == 'M'].count()
# Out:
# AIR               1055
# NEET Roll No.     1055
# CET Form. No.     1055
# Reg. Sr No.       1055
# Name              1055
# G                 1055
# Cat.              1055
# Quota             1055
# Code - College    1055
# dtype: int64

# %%
# gender_column = results['G']
# results.groupby(["G", gender_column]).size().unstack(level=1).plot(kind='bar')
# .rename({True:'Female',False:'Male'})
import matplotlib.pyplot as plt
s = results['G'].value_counts()

s.plot.bar(colors=['r','b'])
plt.bar(Gender, results['Sales'])
# 13 F, 7 M
#M-1063, and F-1823
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-159-965125c3df09> in <module>
#       5 s = results['G'].value_counts()
#       6
# ----> 7 s.plot.bar(colors=['r','b'])
#       8 # 13 F, 7 M
#       9 #M-1063, and F-1823
#
# c:\users\khanmoh\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1105         other axis represents a measured value.
#    1106         """
# -> 1107         return self(kind="bar", x=x, y=y, **kwargs)
#    1108
#    1109     @Appender(
#
# c:\users\khanmoh\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ...

# %%
# Displaying all the rows that has NaN
# naNValue = results[results.isna().any(axis=1)]
# display(naNValue.head())
# all_df_data = all_df_data.dropna(how='all')
results
# Out:
#          AIR NEET Roll No. CET Form. No. Reg. Sr No.  \
# 1     156277     3.104e+09   2.11018e+08       12714
# 2     563596    3101014157     211022699       35167
# 3     285484    3112003248     211008941       21465
# 4     516188    3112001464     211025717       33274
# 5      98564    3115001315     211029186        8220
# ...      ...           ...           ...         ...
# 2882  488365    3114003002     211011655       32113
# 2883  372985   3.11301e+09   2.11037e+08       26627
# 2884  612998   3.11012e+09   2.11035e+08       36900
# 2885  320168    3112107346     211006263       23631
# 2886  328413    3110015004     211020104       24125
#
#                            Name  G Cat.  \
# 1           SHAIKH NAZEEM ABBAS  M  EWS
# 2             SHAIKH AKIB ABBAS  M  NTB
# 3          MUJTABA AHMED ABBASI  M  NTB
# 4              TUBA ANAM ABBASI  F
# 5     MOHAMMAD MUSADDIQUE ABDUL  M  OBC
# ...                         ... ..  ...
# 2882           KHOT ABID ZAMEER  M  EWS
# ...
